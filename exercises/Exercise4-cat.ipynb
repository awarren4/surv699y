# %%
# %run exercise4.py
# Out:
#   File "/Users/antoniawarren/Documents/Surv 699y/surv699y/exercises/exercise4.py", line 48
#     stripped_string = current_line.strip()
#     ^
# IndentationError: unexpected indent

# %%
# %run exercise4.py
# Out:
# current_line:
#
# current_line:Project Gutenberg Etext of Romeo and Juliet by Shakespeare
#
# current_line:PG has multiple editions of William Shakespeare's Complete Works
#
# current_line:
#
# current_line:
#
# current_line:Copyright laws are changing all over the world, be sure to check
#
# current_line:the copyright laws for your country before posting these files!!
#
# current_line:
#
# current_line:Please take a look at the important information in this header.
#
# current_line:We encourage you to keep this file on your own disk, keeping an
#
# current_line:electronic path open for the next readers.  Do not remove this.
#
# current_line:
#
# current_line:
#
# current_line:**Welcome To The World of Free Plain Vanilla Electronic Texts**
#
# current_line:
#
# current_line:**Etexts Readable By Both Humans and By Computers, Since 1971**
#
# current_line:
#
# current_line:*These Etexts Prepared By Hundreds of Volunteers and Donations*
#
# current_line:
#
# ...

# %%
# %run exercise4.py
# Out:
# current_line:
#
# current_line:Project Gutenberg Etext of Romeo and Juliet by Shakespeare
#
# current_line:PG has multiple editions of William Shakespeare's Complete Works
#
# current_line:
#
# current_line:
#
# current_line:Copyright laws are changing all over the world, be sure to check
#
# current_line:the copyright laws for your country before posting these files!!
#
# current_line:
#
# current_line:Please take a look at the important information in this header.
#
# current_line:We encourage you to keep this file on your own disk, keeping an
#
# current_line:electronic path open for the next readers.  Do not remove this.
#
# current_line:
#
# current_line:
#
# current_line:**Welcome To The World of Free Plain Vanilla Electronic Texts**
#
# current_line:
#
# current_line:**Etexts Readable By Both Humans and By Computers, Since 1971**
#
# current_line:
#
# current_line:*These Etexts Prepared By Hundreds of Volunteers and Donations*
#
# current_line:
#
# ...
